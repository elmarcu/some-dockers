# %%
import requests
print(requests.get("http://www.google.com/?=hello world").text)
# Out:
# <!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="es-419"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/logos/doodles/2020/luis-alberto-spinettas-70th-birthday-6753651837108268.2-law.gif" itemprop="image"><meta content="70º aniversario del nacimiento de Luis Alberto Spinetta" property="twitter:title"><meta content="70º aniversario del nacimiento de Luis Alberto Spinetta #GoogleDoodle" property="twitter:description"><meta content="70º aniversario del nacimiento de Luis Alberto Spinetta #GoogleDoodle" property="og:description"><meta content="summary_large_image" property="twitter:card"><meta content="@GoogleDoodles" property="twitter:site"><meta content="https://www.google.com/logos/doodles/2020/luis-alberto-spinettas-70th-birthday-6753651837108268-2xa.gif" property="twitter:image"><meta content="https://www.google.com/logos/doodles/2020/luis-alberto-spinettas-70th-birthday-6753651837108268-2xa.gif" property="og:imag
# ...
